# %% [markdown]
# `BENEFITS OF PIPELINE`
# - alag alag steps ni likhne padte hai
# - har bar preprocessing manually ni krni pdti hai
# - steps miss hone ke chances kam rhte hai
# - training aur testing dono data par same transformation sath hi ho jata hai alag se karne ki need nahi hoti hai

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Numerical and Categorical Columns separation

# %%
num_cols = df.select_dtypes('number').columns
print(num_cols.tolist())
# Out:
# ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']

# %%
cat_cols = df.select_dtypes(exclude='number').columns
print(cat_cols.tolist())
# Out:
# ['species', 'island', 'sex']

# %% [markdown]
# Numerical Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy='mean')),
    ("scaler", StandardScaler())
])

# %% [markdown]
# Categorical Pipeline

# %%
from sklearn.preprocessing import OneHotEncoder

cat_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(drop='first'))
])

# %% [markdown]
# Column Transformer

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer([
    ("num", num_pipeline, num_cols),
    ("cat", cat_pipeline, cat_cols)
])

# %%
transformed_data = preprocessor.fit_transform(df)
transformed_data
# Out:
# array([[-0.88708123,  0.78774251, -1.42248782, ...,  0.        ,
#          1.        ,  1.        ],
#        [-0.81349399,  0.12655633, -1.06535169, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.66631952,  0.43171918, -0.42250666, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 1.1917582 , -0.73807176,  1.50602843, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.23512413, -1.19581604,  0.79175618, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.09977416, -0.53462985,  0.8631834 , ...,  0.        ,
#          0.        ,  1.        ]], shape=(344, 9))
